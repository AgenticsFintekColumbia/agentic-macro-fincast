# %% [markdown]
# \*Please Run in colab

# %% [markdown]
# # Setup

# %% [markdown]
# ### Environment Setup

# %%
# ! apt-get install -y libgraphviz-dev
# ! pip install pygraphviz

# %%
# !pip install instructor

# %%
# !pip install feedparser

# %%
# !pip install langchain langchain-openai

# %%
# !npm install localtunnel
# Out:
# ⠙⠹⠸⠼⠴⠦
# up to date, audited 23 packages in 968ms
# ⠦
# ⠦3 packages are looking for funding
# ⠦  run `npm fund` for details
# ⠦
# 2 high severity vulnerabilities
#
# To address all issues (including breaking changes), run:
#   npm audit fix --force
#
# Run `npm audit` for details.
# ⠦

# %%
# !pip install streamlit

# %%
# !cd /content
# !rm -rf macro_financial_forecasting

# %%
# !git clone https://github.com/chuanbinp/macro_financial_forecasting.git
# Out:
# Cloning into 'macro_financial_forecasting'...
# remote: Enumerating objects: 2444, done.
# remote: Counting objects: 100% (929/929), done.
# remote: Compressing objects: 100% (363/363), done.
# remote: Total 2444 (delta 699), reused 629 (delta 566), pack-reused 1515 (from 3)
# Receiving objects: 100% (2444/2444), 40.71 MiB | 13.01 MiB/s, done.
# Resolving deltas: 100% (1606/1606), done.

# %%
# %cd macro_financial_forecasting/applications/macro_financial_forecasting
# Out:
# /content/macro_financial_forecasting/applications/macro_financial_forecasting/macro_financial_forecasting/applications/macro_financial_forecasting/macro_financial_forecasting/applications/macro_financial_forecasting

# %% [markdown]
# ### Code Setup

# %%
from src.config import Config
from google.colab import userdata
import os

os.environ["OPENAI_API_KEY"] = userdata.get("OPENAI_API_KEY")
config = Config("config.env")
print(f"Config: {config}")
# Out:
# Config: Config(
#   gemini_api_key: !secret!
#   openai_api_key: !secret!
#   llm_model: openai/gpt-5-nano-2025-08-07
#   industries: ['Information Technology', 'Health Care', 'Financials', 'Consumer Discretionary', 'Communication Services', 'Industrials', 'Consumer Staples', 'Energy', 'Utilities', 'Real Estate', 'Materials', 'General Market', 'None']
#   dataset_name: danidanou/Bloomberg_Financial_News
#   dataset_dir: /data/
# ...

# %% [markdown]
# # Agent

# %% [markdown]
# # Run via Streamlit Tunnel

# %%
# !streamlit run app.py &>/content/logs.txt &
# !npx localtunnel --port 8501 --subdomain agentic-macro-fincast
# Out:
# ⠙your url is: https://agentic-macro-fincast.loca.lt
# ^C

# %%
# !wget -q -O - ipv4.icanhazip.com

# %% [markdown]
# #Run inline

# %%
# from src.langgraph.pipeline import build_graph, create_initial_state
# import nest_asyncio
# nest_asyncio.apply()
# Out:
# tokenizer_config.json:   0%|          | 0.00/252 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/758 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/438M [00:00<?, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/558M [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# spm.model:   0%|          | 0.00/4.31M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/16.3M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/23.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/286 [00:00<?, ?B/s]
# Device set to use cpu

# %%
# app = build_graph()
# MODE = "mock"  # or "real"
# days_back = 1

# result = await app.ainvoke(create_initial_state(mode=MODE, days_back=days_back))

# print(result["predictions"])  # Display the final predictions dataframe
# print(result["summary"])
# Out:
# Validating entries: 100%|██████████| 3/3 [00:00<00:00, 16341.44it/s]
# Raw sentiment rows: 3
# Unique mapped tickers in sentiment: ['SPY', 'XLF']
# Tickers: ['SPY', 'XLF']
# OHLCV date range: 2025-08-29 23:44:21 to 2025-11-27 23:44:21
# [*********************100%***********************]  2 of 2 completed
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# OHLCV shape: (62, 10)
# OHLCV columns (first few): [('Close', 'SPY'), ('Close', 'XLF'), ('High', 'SPY'), ('High', 'XLF'), ('Low', 'SPY'), ('Low', 'XLF'), ('Open', 'SPY'), ('Open', 'XLF')]
# ohlcv_long shape: (124, 4)
# model_df shape after OHLCV merge: (3, 20)
# Dropped 0 rows due to missing MKT or SentimentScore.
# Numeric feature matrix shape: (3, 4)
#          Industry                Date  \
# 0  General Market 2025-11-27 22:29:53
# 1      Financials 2025-11-27 23:33:36
# ...

# %%
# from IPython.display import display, Image

# # Get the graph object
# graph = app.get_graph()

# # Render the graph as a PNG image in memory and display it
# display(Image(graph.draw_png()))
